# %% [markdown]
# # Array Data Structure Testing
# Demonstrating OOP principles with Array implementation

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Array Data Structure Demo\n",
    "Simple demonstration of Array operations"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "from array import Array\n",
    "\n",
    "class ArrayDemo:\n",
    "    def __init__(self):\n",
    "        self.array = Array()\n",
    "    \n",
    "    def demo_insert(self, items):\n",
    "        print(\"Inserting elements:\")\n",
    "        for item in items:\n",
    "            self.array.insert(item)\n",
    "        self.array.display()\n",
    "    \n",
    "    def demo_search(self, item):\n",
    "        print(f\"\\nSearching for {item}:\")\n",
    "        result = self.array.search(item)\n",
    "        print(f\"Found at index: {result}\")\n",
    "    \n",
    "    def demo_delete(self, index):\n",
    "        print(f\"\\nDeleting element at index {index}:\")\n",
    "        deleted = self.array.delete(index)\n",
    "        print(f\"Deleted: {deleted}\")\n",
    "        self.array.display()\n",
    "    \n",
    "    def show_array(self):\n",
    "        print(\"\\nCurrent array:\")\n",
    "        self.array.display()\n",
    "        print(f\"Length: {self.array.length()}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Run demonstration\n",
    "demo = ArrayDemo()\n",
    "\n",
    "# Insert elements\n",
    "demo.demo_insert([1, 2, 3, 4])\n",
    "\n",
    "# Search for element\n",
    "demo.demo_search(2)\n",
    "\n",
    "# Delete element\n",
    "demo.demo_delete(1)\n",
    "\n",
    "# Show final state\n",
    "demo.show_array()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
